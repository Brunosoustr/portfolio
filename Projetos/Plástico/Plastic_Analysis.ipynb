# %% [markdown]
# # Análise de Poluição por Plásticos nos Oceanos
#
# ## Contexto
# Este notebook contém a análise exploratória de dados (EDA) sobre a poluição de plásticos nos oceanos. O objetivo é identificar padrões de distribuição, tipos predominantes de plásticos e áreas de maior concentração para orientar estratégias de mitigação.
#
# ## Perguntas Chave
# 1. Qual é a distribuição de peso de plásticos por região?
# 2. Quais tipos de plásticos são mais comuns?
# 3. Existe correlação entre profundidade e acúmulo de plásticos?
# 4. Variações temporais e geográficas.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Configuração de Estilo
sns.set_style('darkgrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ### Carregamento dos Dados

# %%
# Carregar o dataset
# Certifique-se de que o arquivo 'Análise Plástico.xlsx' está na mesma pasta
try:
    df = pd.read_excel('Análise Plástico.xlsx')
    print("Dados carregados com sucesso!")
    display(df.head())
except Exception as e:
    print(f"Erro ao carregar o arquivo: {e}")

# %% [markdown]
# ### Análise Exploratória Inicial

# %%
# Informações gerais
df.info()

# %%
# Estatísticas descritivas
df.describe()

# %% [markdown]
# ### Visualizações

# %%
# Exemplo de Gráfico: Distribuição de Tipos de Plástico (Placeholder)
# Substitua 'Tipo_Plastico' e 'Peso' pelos nomes reais das colunas no seu Excel

if 'Tipo_Plastico' in df.columns:
    plt.figure(figsize=(10, 6))
    sns.countplot(data=df, x='Tipo_Plastico', palette='viridis')
    plt.title('Contagem por Tipo de Plástico')
    plt.show()

# %% [markdown]
# ### Conclusões Preliminares
# *Este espaço é reservado para as conclusões baseadas na execução real dos dados acima.*
